# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
weeks = ['week12',
         'week34',
         'week56']

week = weeks[1]
ddir = '/glade/derecho/scratch/kjmayer/DATA/CESM2-S2S/'
finame_X1 = 'tas_2m_anom_cesm2cam6v2_04jan1999-28dec2020_00z_initmean_m00-10mean.nc'
finame_X2 = 'tas_2m_anom_cesm2cam6v2_04jan1999-28dec2020_00z_'+week+'mean_m00-10mean.nc'
finame_Y = 'tas_2m_anom_ERA5_04jan1999-28dec2020_'+week+'mean.nc'

# %%
X1 = xr.open_dataset(ddir+finame_X1)['tas_2m']
X2 = xr.open_dataset(ddir+finame_X2)['tas_2m']
Y = xr.open_dataset(ddir+finame_Y)['tas_2m']

# %%
X1[0].plot()

# %%
X2[0].plot()

# %%
Y[0].plot()
