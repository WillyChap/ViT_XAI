# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# ## Functions

# %%
class RegressionCNN(nn.Module):
    def __init__(self, input_shape, num_classes=9):
        """
        Initialize the CNN model.
        
        Parameters:
            input_shape (tuple): The shape of the input images (C, H, W).
            num_classes (int): The number of classes for prediction.
        """
        super(RegressionCNN, self).__init__()
        self.flatten = nn.Flatten()
        
        self.conv1 = nn.Conv2d(in_channels=input_shape[0], out_channels=32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        
        # Calculate the size of the flattened features after conv and pooling layers
        self.flattened_size = 64 * (input_shape[1] // 4) * (input_shape[2] // 4)
        
        self.fc1 = nn.Linear(self.flattened_size, 128)
        self.fc2 = nn.Linear(128, num_classes)
        
    def forward(self, x):
        """
        Forward pass through the model.
        
        Parameters:
            x (torch.Tensor): Input tensor.
        
        Returns:
            torch.Tensor: The output of the network.
        """
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        # x = x.view(-1, self.flattened_size)  # Flatten the tensor for the fully connected layer
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


class RegressionANN(nn.Module):
    def __init__(self, input_shape, num_classes=9):
        """
        Initialize the CNN model.
        
        Parameters:
            input_shape (tuple): The shape of the input images (C, H, W).
            num_classes (int): The number of classes for prediction.
        """
        super(RegressionANN, self).__init__()
        
        # Calculate the size of the flattened features after conv and pooling layers
        self.flattened_size = (input_shape[1]) * (input_shape[2])

        self.flatten = nn.Flatten()
        self.fc0 = nn.Linear(self.flattened_size,1024)
        self.fc1 = nn.Linear(1024,512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 32)
        self.fc6 = nn.Linear(32, 16)
        self.fc7 = nn.Linear(16, num_classes)
        
    def forward(self, x):
        """
        Forward pass through the model.
        
        Parameters:
            x (torch.Tensor): Input tensor.
        
        Returns:
            torch.Tensor: The output of the network.
        """
        x = self.flatten(x)
        # x = x.view(-1, self.flattened_size)  # Flatten the tensor for the fully connected layer
        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = F.relu(self.fc6(x))
        x = (self.fc7(x))
        return x

class Regression_Linear(nn.Module):
    def __init__(self, input_shape, num_classes=9):
        """
        Initialize the CNN model.
        
        Parameters:
            input_shape (tuple): The shape of the input images (C, H, W).
            num_classes (int): The number of classes for prediction.
        """
        super(Regression_Linear, self).__init__()
        
        # Calculate the size of the flattened features after conv and pooling layers
        self.flattened_size = (input_shape[1]) * (input_shape[2])
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(self.flattened_size,num_classes)
        
    def forward(self, x):
        """
        Forward pass through the model.
        
        Parameters:
            x (torch.Tensor): Input tensor.
        
        Returns:
            torch.Tensor: The output of the network.
        """
        # x = x.view(-1, self.flattened_size)  # Flatten the tensor for the fully connected layer
        x = self.flatten(x)
        x = (self.fc1(x))
        return x


class SpatialDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.nan_to_num(torch.tensor(X, dtype=torch.float32))
        self.y = torch.tensor(y, dtype=torch.float32)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

class SpatialDataset_ANN(Dataset):
    def __init__(self, X, y):
        self.X = torch.nan_to_num(torch.tensor(X, dtype=torch.float32)).squeeze()
        self.y = torch.tensor(y, dtype=torch.float32)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx].unsqueeze(0)

# %% [markdown]
# ## Import Dataset

# %%
Data_ = xr.open_dataset('../Data_Staging/Mamalakis_Dataset/scp_synth_exm_data.nc')
Data_train = np.expand_dims(Data_['SSTrand'].isel(time=slice(0,900000)),1)
Y_train = np.array(Data_['y'].isel(time=slice(0,900000)))

Data_val = np.expand_dims(Data_['SSTrand'].isel(time=slice(950000,1000000)),1)
Y_val = np.array(Data_['y'].isel(time=slice(950000,1000000)))

Data_test = np.expand_dims(Data_['SSTrand'].isel(time=slice(900000,950000)),1)
Y_test = np.array(Data_['y'].isel(time=slice(900000,950000)))

# %% [markdown]
# ## Train Model

# %%
rem = Data_train.shape
input_shape = (rem[1],rem[2],rem[3]) # Example input shape (C, H, W)
model = RegressionCNN(input_shape=input_shape, num_classes=1)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.02)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, verbose=True)

train_dataset = SpatialDataset(Data_train, Y_train)
val_dataset = SpatialDataset(Data_val, Y_val)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
num_epochs = 200

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    print(f"Starting Epoch {epoch}")
    nsampsseen = 0
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        nsampsseen += inputs.shape[0]
        if nsampsseen > 10000:
            break
    epoch_loss = running_loss / nsampsseen
    print(f"Epoch {epoch}, Loss: {epoch_loss:.4f}")

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    mse_val_batch=[]
    with torch.no_grad():  # In validation phase, we don't need to compute gradients
        for inputs, labels in val_loader:
            outputs = model(inputs)
            mse_val_batch.append((torch.mean((outputs-labels)**2)))
            
    # Calculate and print validation accuracy
    mse_tot=torch.mean(torch.tensor(mse_val_batch))
    
    print(f"MSE: {mse_tot:.5f}")
    print( f"r2: {1-(mse_tot/np.var(Y_val))}")
    
    if epoch == 0:
        print('...saved first epoch...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    elif mse_tot<best_acc:
        print('...saving!...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    else:
        print('No improvement in validation accuracy.')
    # Step the scheduler on each epoch
    scheduler.step(mse_tot)

# %% [markdown]
# ## ANN

# %%
rem = Data_train.shape
input_shape = (rem[1],rem[2],rem[3]) # Example input shape (C, H, W)
model = RegressionANN(input_shape=input_shape, num_classes=1)
model.fc0.weight.data = torch.normal(mean=0,std=(1/648),size=(1024, 648))
model.fc0.bias.data.fill_(0)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.02)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, verbose=True)

train_dataset = SpatialDataset_ANN(Data_train,Y_train)
val_dataset = SpatialDataset_ANN(Data_val,Y_val)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
num_epochs = 200

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    print(f"Starting Epoch {epoch}")
    nsampsseen = 0
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        nsampsseen += inputs.shape[0]
        if nsampsseen > 40000:
            break
    epoch_loss = running_loss / nsampsseen
    print(f"Epoch {epoch}, Loss: {epoch_loss:.4f}")

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    mse_val_batch=[]
    with torch.no_grad():  # In validation phase, we don't need to compute gradients
        for inputs, labels in val_loader:
            outputs = model(inputs)
            mse_val_batch.append((torch.mean((outputs-labels)**2)))
            
    # Calculate and print validation accuracy
    mse_tot=torch.mean(torch.tensor(mse_val_batch))
    
    print(f"MSE: {mse_tot:.5f}")
    print( f"r2: {1-(mse_tot/np.var(Y_val))}")
    
    if epoch == 0:
        print('...saved first epoch...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    elif mse_tot<best_acc:
        print('...saving!...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    else:
        print('No improvement in validation accuracy.')
    # Step the scheduler on each epoch
    scheduler.step(mse_tot)
# Out:
# Starting Epoch 0
# Epoch 0, Loss: 0.0533
# MSE: 0.00925
# r2: -9.012222290039062e-05
# ...saved first epoch...
# Starting Epoch 1
# Epoch 1, Loss: 0.0092
# MSE: 0.00926
# r2: -0.0020064115524291992
# No improvement in validation accuracy.
# Starting Epoch 2
# Epoch 2, Loss: 0.0093
# MSE: 0.00927
# r2: -0.0027763843536376953
# No improvement in validation accuracy.
# Starting Epoch 3
# Epoch 3, Loss: 0.0093
# MSE: 0.00929
# r2: -0.005290031433105469
# No improvement in validation accuracy.
# Starting Epoch 4
# Epoch 4, Loss: 0.0095
# MSE: 0.00925
# r2: -0.0007610321044921875
# No improvement in validation accuracy.
# Starting Epoch 5
# Epoch 5, Loss: 0.0094
# MSE: 0.00934
# r2: -0.01026773452758789
# No improvement in validation accuracy.
# Starting Epoch 6
# Epoch 6, Loss: 0.0094
# MSE: 0.00935
# r2: -0.011784672737121582
# No improvement in validation accuracy.
# Starting Epoch 7
# Epoch 7, Loss: 0.0093
# MSE: 0.00931
# r2: -0.007256865501403809
# No improvement in validation accuracy.
# Starting Epoch 8
# Epoch 8, Loss: 0.0094
# MSE: 0.00925
# r2: -0.0005452632904052734
# No improvement in validation accuracy.
# Starting Epoch 9
# Epoch 9, Loss: 0.0094
# MSE: 0.00926
# r2: -0.0018444061279296875
# No improvement in validation accuracy.
# Starting Epoch 10
# Epoch 10, Loss: 0.0095
# MSE: 0.00925
# r2: -0.0006505250930786133
# No improvement in validation accuracy.
# Starting Epoch 11
# Epoch 11, Loss: 0.0093
# MSE: 0.00929
# r2: -0.005318641662597656
# No improvement in validation accuracy.
# Starting Epoch 12
# Epoch 12, Loss: 0.0094
# MSE: 0.00934
# r2: -0.01063072681427002
# No improvement in validation accuracy.
# Starting Epoch 13
# Epoch 13, Loss: 0.0093
# MSE: 0.00926
# r2: -0.0015077590942382812
# No improvement in validation accuracy.
# Starting Epoch 14
# Epoch 14, Loss: 0.0094
# MSE: 0.00925
# r2: -0.00020015239715576172
# No improvement in validation accuracy.
# Starting Epoch 15
# Epoch 15, Loss: 0.0094
# MSE: 0.00926
# r2: -0.001502394676208496
# No improvement in validation accuracy.
# Starting Epoch 16
# Epoch 16, Loss: 0.0093
# MSE: 0.00929
# r2: -0.00477290153503418
# No improvement in validation accuracy.
# Starting Epoch 17
# Epoch 17, Loss: 0.0093
# MSE: 0.00930
# r2: -0.005776762962341309
# No improvement in validation accuracy.
# Starting Epoch 18
# Epoch 18, Loss: 0.0093
# MSE: 0.00945
# r2: -0.021867752075195312
# No improvement in validation accuracy.
# Starting Epoch 19
# Epoch 19, Loss: 0.0094
# MSE: 0.00928
# r2: -0.004224181175231934
# No improvement in validation accuracy.
# Starting Epoch 20
# Epoch 20, Loss: 0.0094
# MSE: 0.00926
# r2: -0.001821279525756836
# No improvement in validation accuracy.
# Starting Epoch 21
# Epoch 21, Loss: 0.0094
# MSE: 0.00940
# r2: -0.017081499099731445
# No improvement in validation accuracy.
# Epoch 00022: reducing learning rate of group 0 to 1.0000e-02.
# Starting Epoch 22
# Epoch 22, Loss: 0.0093
# MSE: 0.00931
# r2: -0.007125973701477051
# No improvement in validation accuracy.
# Starting Epoch 23
# Epoch 23, Loss: 0.0093
# MSE: 0.00945
# r2: -0.022399544715881348
# No improvement in validation accuracy.
# Starting Epoch 24
# Epoch 24, Loss: 0.0094
# MSE: 0.00924
# r2: 8.469820022583008e-05
# ...saving!...
# Starting Epoch 25
# Epoch 25, Loss: 0.0093
# MSE: 0.00924
# r2: 4.2319297790527344e-05
# No improvement in validation accuracy.
# Starting Epoch 26
# Epoch 26, Loss: 0.0093
# MSE: 0.00925
# r2: -0.000148773193359375
# No improvement in validation accuracy.
# Starting Epoch 27
# Epoch 27, Loss: 0.0093
# MSE: 0.00924
# r2: 9.769201278686523e-05
# ...saving!...
# Starting Epoch 28
# Epoch 28, Loss: 0.0093
# MSE: 0.00925
# r2: -0.0006678104400634766
# No improvement in validation accuracy.
# Starting Epoch 29
# Epoch 29, Loss: 0.0093
# MSE: 0.00934
# r2: -0.01047670841217041
# No improvement in validation accuracy.
# Starting Epoch 30
# Epoch 30, Loss: 0.0093
# MSE: 0.00925
# r2: -0.0007088184356689453
# No improvement in validation accuracy.
# Starting Epoch 31
# Epoch 31, Loss: 0.0093
# MSE: 0.00942
# r2: -0.018610000610351562
# No improvement in validation accuracy.
# Starting Epoch 32
# Epoch 32, Loss: 0.0093
# MSE: 0.00944
# r2: -0.020718812942504883
# No improvement in validation accuracy.
# Starting Epoch 33
# Epoch 33, Loss: 0.0093
# MSE: 0.00925
# r2: -7.081031799316406e-05
# No improvement in validation accuracy.
# Starting Epoch 34
# Epoch 34, Loss: 0.0094
# MSE: 0.00925
# r2: -0.0002771615982055664
# No improvement in validation accuracy.
# Starting Epoch 35
# Epoch 35, Loss: 0.0092
# MSE: 0.00949
# r2: -0.0262373685836792
# No improvement in validation accuracy.
# Starting Epoch 36
# Epoch 36, Loss: 0.0093
# MSE: 0.00925
# r2: -0.000972747802734375
# No improvement in validation accuracy.
# Starting Epoch 37
# Epoch 37, Loss: 0.0093
# MSE: 0.00925
# r2: -0.00034928321838378906
# No improvement in validation accuracy.
# Starting Epoch 38
# Epoch 38, Loss: 0.0093
# MSE: 0.01029
# r2: -0.11348092555999756
# No improvement in validation accuracy.
# Starting Epoch 39
# Epoch 39, Loss: 0.0092
# MSE: 0.00957
# r2: -0.03532528877258301
# No improvement in validation accuracy.
# Starting Epoch 40
# Epoch 40, Loss: 0.0093
# MSE: 0.00926
# r2: -0.0017960071563720703
# No improvement in validation accuracy.
# Starting Epoch 41
# Epoch 41, Loss: 0.0093
# MSE: 0.00931
# r2: -0.006538510322570801
# No improvement in validation accuracy.
# Starting Epoch 42
# Epoch 42, Loss: 0.0093
# MSE: 0.00924
# r2: 8.046627044677734e-05
# No improvement in validation accuracy.
# Starting Epoch 43
# Epoch 43, Loss: 0.0093
# MSE: 0.00928
# r2: -0.0037729740142822266
# No improvement in validation accuracy.
# Starting Epoch 44
# Epoch 44, Loss: 0.0093
# MSE: 0.00924
# r2: 2.0444393157958984e-05
# No improvement in validation accuracy.
# Starting Epoch 45
# Epoch 45, Loss: 0.0092
# MSE: 0.00925
# r2: -0.0002015829086303711
# No improvement in validation accuracy.
# Epoch 00046: reducing learning rate of group 0 to 5.0000e-03.
# Starting Epoch 46
# Epoch 46, Loss: 0.0093
# MSE: 0.00929
# r2: -0.004483938217163086
# No improvement in validation accuracy.
# Starting Epoch 47
# Epoch 47, Loss: 0.0092
# MSE: 0.00927
# r2: -0.0029549598693847656
# No improvement in validation accuracy.
# Starting Epoch 48
# Epoch 48, Loss: 0.0092
# MSE: 0.00925
# r2: -0.0002733469009399414
# No improvement in validation accuracy.
# Starting Epoch 49
# Epoch 49, Loss: 0.0093
# MSE: 0.00928
# r2: -0.0034748315811157227
# No improvement in validation accuracy.
# Starting Epoch 50
# Epoch 50, Loss: 0.0092
# MSE: 0.00927
# r2: -0.0023537874221801758
# No improvement in validation accuracy.
# Starting Epoch 51
# Epoch 51, Loss: 0.0092
# MSE: 0.00924
# r2: 9.60230827331543e-05
# No improvement in validation accuracy.
# Starting Epoch 52
# Epoch 52, Loss: 0.0093
# MSE: 0.00926
# r2: -0.0016281604766845703
# No improvement in validation accuracy.
# Starting Epoch 53
# Epoch 53, Loss: 0.0092
# MSE: 0.00931
# r2: -0.0067713260650634766
# No improvement in validation accuracy.
# Starting Epoch 54
# Epoch 54, Loss: 0.0092
# MSE: 0.00927
# r2: -0.002753019332885742
# No improvement in validation accuracy.
# Starting Epoch 55
# Epoch 55, Loss: 0.0093
# MSE: 0.00928
# r2: -0.0038679838180541992
# No improvement in validation accuracy.
# Starting Epoch 56
# Epoch 56, Loss: 0.0093
# MSE: 0.00929
# r2: -0.004773378372192383
# No improvement in validation accuracy.
# Starting Epoch 57
# Epoch 57, Loss: 0.0092
# MSE: 0.00925
# r2: -0.0005918741226196289
# No improvement in validation accuracy.
# Starting Epoch 58
# Epoch 58, Loss: 0.0094
# MSE: 0.00924
# r2: 4.470348358154297e-05
# No improvement in validation accuracy.
# Starting Epoch 59
# Epoch 59, Loss: 0.0093
# MSE: 0.00925
# r2: -4.3272972106933594e-05
# No improvement in validation accuracy.
# Starting Epoch 60
# Epoch 60, Loss: 0.0094
# MSE: 0.00931
# r2: -0.007105112075805664
# No improvement in validation accuracy.
# Starting Epoch 61
# Epoch 61, Loss: 0.0092
# MSE: 0.00938
# r2: -0.014272451400756836
# No improvement in validation accuracy.
# Starting Epoch 62
# Epoch 62, Loss: 0.0092
# MSE: 0.00925
# r2: -0.00021827220916748047
# No improvement in validation accuracy.
# Starting Epoch 63
# Epoch 63, Loss: 0.0092
# MSE: 0.00936
# r2: -0.012120842933654785
# No improvement in validation accuracy.
# Starting Epoch 64
# Epoch 64, Loss: 0.0093
# MSE: 0.00933
# r2: -0.009144783020019531
# No improvement in validation accuracy.
# Starting Epoch 65
# Epoch 65, Loss: 0.0092
# MSE: 0.00925
# r2: -0.00023472309112548828
# No improvement in validation accuracy.
# Starting Epoch 66
# Epoch 66, Loss: 0.0093
# MSE: 0.00925
# r2: -8.511543273925781e-05
# No improvement in validation accuracy.
# Epoch 00067: reducing learning rate of group 0 to 2.5000e-03.
# Starting Epoch 67
# Epoch 67, Loss: 0.0093
# MSE: 0.00925
# r2: -0.0003371238708496094
# No improvement in validation accuracy.
# Starting Epoch 68
# Epoch 68, Loss: 0.0093
# MSE: 0.00924
# r2: 8.940696716308594e-06
# No improvement in validation accuracy.
# Starting Epoch 69
# Epoch 69, Loss: 0.0093
# MSE: 0.00925
# r2: -0.0006835460662841797
# No improvement in validation accuracy.
# Starting Epoch 70
# Epoch 70, Loss: 0.0093
# MSE: 0.00930
# r2: -0.0063135623931884766
# No improvement in validation accuracy.
# Starting Epoch 71
# Epoch 71, Loss: 0.0093
# MSE: 0.00924
# r2: 7.37309455871582e-05
# No improvement in validation accuracy.
# Starting Epoch 72
# Epoch 72, Loss: 0.0093
# MSE: 0.00927
# r2: -0.0022127628326416016
# No improvement in validation accuracy.
# Starting Epoch 73
# Epoch 73, Loss: 0.0093
# MSE: 0.00925
# r2: -0.00026297569274902344
# No improvement in validation accuracy.
# Starting Epoch 74
# Epoch 74, Loss: 0.0093
# MSE: 0.00929
# r2: -0.00462496280670166
# No improvement in validation accuracy.
# Starting Epoch 75
# Epoch 75, Loss: 0.0092
# MSE: 0.00931
# r2: -0.006555438041687012
# No improvement in validation accuracy.
# Starting Epoch 76
# Epoch 76, Loss: 0.0093
# MSE: 0.00925
# r2: 1.7881393432617188e-06
# No improvement in validation accuracy.
# Starting Epoch 77
# Epoch 77, Loss: 0.0093
# MSE: 0.00928
# r2: -0.004021167755126953
# No improvement in validation accuracy.
# Starting Epoch 78
# Epoch 78, Loss: 0.0092
# MSE: 0.00925
# r2: -0.0007737874984741211
# No improvement in validation accuracy.
# Starting Epoch 79
# Epoch 79, Loss: 0.0092
# MSE: 0.00925
# r2: -0.0006959438323974609
# No improvement in validation accuracy.
# Starting Epoch 80
# Epoch 80, Loss: 0.0092
# MSE: 0.00926
# r2: -0.001194596290588379
# No improvement in validation accuracy.
# Starting Epoch 81
# Epoch 81, Loss: 0.0093
# MSE: 0.00925
# r2: -3.0875205993652344e-05
# No improvement in validation accuracy.
# Starting Epoch 82
# Epoch 82, Loss: 0.0093
# MSE: 0.00927
# r2: -0.002329587936401367
# No improvement in validation accuracy.
# Starting Epoch 83
# Epoch 83, Loss: 0.0092
# MSE: 0.00924
# r2: 3.528594970703125e-05
# No improvement in validation accuracy.
# Starting Epoch 84
# Epoch 84, Loss: 0.0092
# MSE: 0.00925
# r2: -0.0004553794860839844
# No improvement in validation accuracy.
# Starting Epoch 85

# %%
plt.plot(labels.detach().numpy())
plt.plot(outputs.detach().numpy())
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
rem = Data_train.shape
input_shape = (rem[1],rem[2],rem[3]) # Example input shape (C, H, W)
model = Regression_Linear(input_shape=input_shape, num_classes=1)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.02)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

train_dataset = SpatialDataset_ANN(Data_train,Y_train)
val_dataset = SpatialDataset_ANN(Data_val,Y_val)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
num_epochs = 200

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    print(f"Starting Epoch {epoch}")
    nsampsseen = 0
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        nsampsseen += inputs.shape[0]
        if nsampsseen > 100000:
            break
    epoch_loss = running_loss / nsampsseen
    print(f"Epoch {epoch}, Loss: {epoch_loss:.4f}")

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    mse_val_batch=[]
    with torch.no_grad():  # In validation phase, we don't need to compute gradients
        for inputs, labels in val_loader:
            outputs = model(inputs)
            mse_val_batch.append((torch.mean((outputs-labels)**2)))
            
    # Calculate and print validation accuracy
    mse_tot=torch.mean(torch.tensor(mse_val_batch))
    
    print(f"MSE: {mse_tot:.5f}")
    print( f"r2: {1-(mse_tot/np.var(Y_val))}")
    
    if epoch == 0:
        print('...saved first epoch...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    elif mse_tot<best_acc:
        print('...saving!...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    else:
        print('No improvement in validation accuracy.')
    # Step the scheduler on each epoch
    scheduler.step(mse_tot)
# Out:
# Starting Epoch 0
# Epoch 0, Loss: 0.1069
# MSE: 0.08134
# r2: -7.798417091369629
# ...saved first epoch...
# Starting Epoch 1
# Epoch 1, Loss: 0.0950
# MSE: 0.09404
# r2: -9.17148494720459
# No improvement in validation accuracy.
# Starting Epoch 2
# Epoch 2, Loss: 0.1150
# MSE: 0.01892
# r2: -1.0464820861816406
# ...saving!...
# Starting Epoch 3
# Epoch 3, Loss: 0.1112
# MSE: 0.01589
# r2: -0.7184035778045654
# ...saving!...
# Starting Epoch 4
# Epoch 4, Loss: 0.0937
# MSE: 0.15636
# r2: -15.912834167480469
# No improvement in validation accuracy.
# Starting Epoch 5
# Epoch 5, Loss: 0.1111
# MSE: 0.09800
# r2: -9.599940299987793
# No improvement in validation accuracy.
# Starting Epoch 6
# Epoch 6, Loss: 0.0992
# MSE: 0.02661
# r2: -1.8779819011688232
# No improvement in validation accuracy.
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-03.
# Starting Epoch 7
# Epoch 7, Loss: 0.0246
# MSE: 0.01161
# r2: -0.255520224571228
# ...saving!...
# Starting Epoch 8
# Epoch 8, Loss: 0.0311
# MSE: 0.01253
# r2: -0.35570454597473145
# No improvement in validation accuracy.
# Starting Epoch 9
# Epoch 9, Loss: 0.0356
# MSE: 0.01240
# r2: -0.34080076217651367
# No improvement in validation accuracy.
# Starting Epoch 10
# Epoch 10, Loss: 0.0332
# MSE: 0.01199
# r2: -0.29729580879211426
# No improvement in validation accuracy.
# Epoch 00015: reducing learning rate of group 0 to 2.5000e-03.
# Starting Epoch 11
# Epoch 11, Loss: 0.0132
# MSE: 0.01063
# r2: -0.14940130710601807
# ...saving!...
# Starting Epoch 12
# Epoch 12, Loss: 0.0158
# MSE: 0.01057
# r2: -0.14384186267852783
# ...saving!...
# Starting Epoch 13
# Epoch 13, Loss: 0.0158
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 27
#      25 mse_val_batch=[]
#      26 with torch.no_grad():  # In validation phase, we don't need to compute gradients
# ---> 27     for inputs, labels in val_loader:
#      28         outputs = model(inputs)
#      29         mse_val_batch.append((torch.mean((outputs-labels)**2)))
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# KeyboardInterrupt:

# %%
plt.plot(labels.detach().numpy())
plt.plot(outputs.detach().numpy())
