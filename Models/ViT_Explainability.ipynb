# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# ## Functions

# %%
class RegressionCNN(nn.Module):
    def __init__(self, input_shape, num_classes=9):
        """
        Initialize the CNN model.
        
        Parameters:
            input_shape (tuple): The shape of the input images (C, H, W).
            num_classes (int): The number of classes for prediction.
        """
        super(RegressionCNN, self).__init__()
        self.flatten = nn.Flatten()
        
        self.conv1 = nn.Conv2d(in_channels=input_shape[0], out_channels=32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        
        # Calculate the size of the flattened features after conv and pooling layers
        self.flattened_size = 64 * (input_shape[1] // 4) * (input_shape[2] // 4)
        
        self.fc1 = nn.Linear(self.flattened_size, 128)
        self.fc2 = nn.Linear(128, num_classes)
        
    def forward(self, x):
        """
        Forward pass through the model.
        
        Parameters:
            x (torch.Tensor): Input tensor.
        
        Returns:
            torch.Tensor: The output of the network.
        """
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        # x = x.view(-1, self.flattened_size)  # Flatten the tensor for the fully connected layer
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


class RegressionANN(nn.Module):
    def __init__(self, input_shape, num_classes=9):
        """
        Initialize the CNN model.
        
        Parameters:
            input_shape (tuple): The shape of the input images (C, H, W).
            num_classes (int): The number of classes for prediction.
        """
        super(RegressionANN, self).__init__()
        
        # Calculate the size of the flattened features after conv and pooling layers
        self.flattened_size = (input_shape[1])

        self.flatten = nn.Flatten()
        self.fc0 = nn.Linear(self.flattened_size,1024)
        self.fc1 = nn.Linear(1024,512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 32)
        self.fc6 = nn.Linear(32, 16)
        self.fc7 = nn.Linear(16, num_classes)
        
    def forward(self, x):
        """
        Forward pass through the model.
        
        Parameters:
            x (torch.Tensor): Input tensor.
        
        Returns:
            torch.Tensor: The output of the network.
        """
        # x = x.view(-1, self.flattened_size)  # Flatten the tensor for the fully connected layer
        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = F.relu(self.fc6(x))
        x = (self.fc7(x))
        return x

class Regression_Linear(nn.Module):
    def __init__(self, input_shape, num_classes=9):
        """
        Initialize the CNN model.
        
        Parameters:
            input_shape (tuple): The shape of the input images (C, H, W).
            num_classes (int): The number of classes for prediction.
        """
        super(Regression_Linear, self).__init__()
        
        # Calculate the size of the flattened features after conv and pooling layers
        self.flattened_size = (input_shape[1]) * (input_shape[2])
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(self.flattened_size,num_classes)
        
    def forward(self, x):
        """
        Forward pass through the model.
        
        Parameters:
            x (torch.Tensor): Input tensor.
        
        Returns:
            torch.Tensor: The output of the network.
        """
        # x = x.view(-1, self.flattened_size)  # Flatten the tensor for the fully connected layer
        x = self.flatten(x)
        x = (self.fc1(x))
        return x


class SpatialDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.nan_to_num(torch.tensor(X, dtype=torch.float32))
        self.y = torch.tensor(y, dtype=torch.float32)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx].unsqueeze(0)

class SpatialDataset_ANN(Dataset):
    def __init__(self, X, y):
        # Convert inputs to tensors
        X_tensor = torch.tensor(X, dtype=torch.float32)
        y_tensor = torch.tensor(y, dtype=torch.float32)
        
        # Flatten X_tensor to check for NaNs across all dimensions of each sample
        flattened_X = X_tensor.view(X_tensor.size(0), -1)
        
        # Identify samples with NaN in either X or y
        mask = ~torch.isnan(flattened_X).any(dim=0)
        
        # Filter out samples where either X or y has NaN
        self.X = flattened_X[:, mask]
        self.y = y_tensor
    
    def __len__(self):
        # The length of the dataset is the length of the cleaned X or y
        return len(self.X)
    
    def __getitem__(self, idx):
        # Get an item and return it, ensure y is returned with an extra dimension if needed
        return self.X[idx], self.y[idx].unsqueeze(0)

# Example usage:
# Assuming X and y are loaded as Numpy arrays or similar format that can be directly converted to tensors.
# This example assumes X and y have been loaded with the shapes X.shape = (900000, 1, 36, 18) and y.shape = (900000,)
# and includes potential NaN values within them.

# dataset = SpatialDataset_ANN(X, y)
# print(dataset[0])  # This will print the first valid sample (index may vary based on NaN distribution).

# %% [markdown]
# ## Import Dataset

# %%
dir_fil = '/glade/work/wchapman/ViT_XAI/Data_Staging/Mamalakis_Dataset/scp_synth_exm_data.nc'
Data_ = xr.open_dataset(dir_fil)
Data_train = np.expand_dims(Data_['SSTrand'].isel(time=slice(0,900000)),1)
Y_train = np.array(Data_['y'].isel(time=slice(0,900000)))

Data_val = np.expand_dims(Data_['SSTrand'].isel(time=slice(950000,1000000)),1)
Y_val = np.array(Data_['y'].isel(time=slice(950000,1000000)))

Data_test = np.expand_dims(Data_['SSTrand'].isel(time=slice(900000,950000)),1)
Y_test = np.array(Data_['y'].isel(time=slice(900000,950000)))

# %% [markdown]
# ## Train Model

# %%
rem = Data_train.shape
input_shape = (rem[1],rem[2],rem[3]) # Example input shape (C, H, W)
model = RegressionCNN(input_shape=input_shape, num_classes=1)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, verbose=True)

train_dataset = SpatialDataset(Data_train, Y_train)
val_dataset = SpatialDataset(Data_val, Y_val)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
num_epochs = 200

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    print(f"Starting Epoch {epoch}")
    nsampsseen = 0
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        nsampsseen += inputs.shape[0]
        if nsampsseen > 10000:
            break
    epoch_loss = running_loss / nsampsseen
    print(f"Epoch {epoch}, Loss: {epoch_loss:.4f}")

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    mse_val_batch=[]
    with torch.no_grad():  # In validation phase, we don't need to compute gradients
        for inputs, labels in val_loader:
            outputs = model(inputs)
            mse_val_batch.append((torch.mean((outputs-labels)**2)))
            
    # Calculate and print validation accuracy
    mse_tot=torch.mean(torch.tensor(mse_val_batch))
    
    print(f"MSE: {mse_tot:.5f}")
    print( f"r2: {1-(mse_tot/np.var(Y_val))}")
    
    if epoch == 0:
        print('...saved first epoch...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    elif mse_tot<best_acc:
        print('...saving!...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    else:
        print('No improvement in validation accuracy.')
    # Step the scheduler on each epoch
    scheduler.step(mse_tot)
# Out:
# Starting Epoch 0
# Epoch 0, Loss: 0.0019
# MSE: 0.00095
# r2: 0.8973406553268433
# ...saved first epoch...
# Starting Epoch 1
# Epoch 1, Loss: 0.0008
# MSE: 0.00071
# r2: 0.9236310124397278
# ...saving!...
# Starting Epoch 2
# Epoch 2, Loss: 0.0006
# MSE: 0.00073
# r2: 0.9213271737098694
# No improvement in validation accuracy.
# Starting Epoch 3
# Epoch 3, Loss: 0.0005
# MSE: 0.00057
# r2: 0.9388746619224548
# ...saving!...
# Starting Epoch 4
# Epoch 4, Loss: 0.0005
# MSE: 0.00053
# r2: 0.9423966407775879
# ...saving!...
# Starting Epoch 5
# Epoch 5, Loss: 0.0004
# MSE: 0.00050
# r2: 0.9456225633621216
# ...saving!...
# Starting Epoch 6
# Epoch 6, Loss: 0.0004
# MSE: 0.00070
# r2: 0.9241554141044617
# No improvement in validation accuracy.
# Starting Epoch 7
# Epoch 7, Loss: 0.0003
# MSE: 0.00075
# r2: 0.9192225337028503
# No improvement in validation accuracy.
# Starting Epoch 8
# Epoch 8, Loss: 0.0003
# MSE: 0.00073
# r2: 0.9205191135406494
# No improvement in validation accuracy.
# Starting Epoch 9
# Epoch 9, Loss: 0.0003
# MSE: 0.00065
# r2: 0.9292823672294617
# No improvement in validation accuracy.
# Starting Epoch 10
# Epoch 10, Loss: 0.0002
# MSE: 0.00062
# r2: 0.9326773285865784
# No improvement in validation accuracy.
# Starting Epoch 11
# Epoch 11, Loss: 0.0002
# MSE: 0.00060
# r2: 0.9356127381324768
# No improvement in validation accuracy.
# Starting Epoch 12
# Epoch 12, Loss: 0.0002
# MSE: 0.00058
# r2: 0.936778724193573
# No improvement in validation accuracy.
# Starting Epoch 13
# Epoch 13, Loss: 0.0001
# MSE: 0.00058
# r2: 0.9371465444564819
# No improvement in validation accuracy.
# Starting Epoch 14
# Epoch 14, Loss: 0.0001
# MSE: 0.00058
# r2: 0.9372519254684448
# No improvement in validation accuracy.
# Starting Epoch 15
# Epoch 15, Loss: 0.0001
# MSE: 0.00059
# r2: 0.935905933380127
# No improvement in validation accuracy.
# Starting Epoch 16
# Epoch 16, Loss: 0.0001
# MSE: 0.00062
# r2: 0.9332252144813538
# No improvement in validation accuracy.
# Starting Epoch 17
# Epoch 17, Loss: 0.0001
# MSE: 0.00075
# r2: 0.9189047813415527
# No improvement in validation accuracy.
# Starting Epoch 18
# Epoch 18, Loss: 0.0002
# MSE: 0.00059
# r2: 0.9358453154563904
# No improvement in validation accuracy.
# Starting Epoch 19
# Epoch 19, Loss: 0.0003
# MSE: 0.00048
# r2: 0.9480385184288025
# ...saving!...
# Starting Epoch 20
# Epoch 20, Loss: 0.0002
# MSE: 0.00047
# r2: 0.9488934278488159
# ...saving!...
# Starting Epoch 21
# Epoch 21, Loss: 0.0002
# MSE: 0.00047
# r2: 0.9487097859382629
# No improvement in validation accuracy.
# Starting Epoch 22
# Epoch 22, Loss: 0.0001
# MSE: 0.00049
# r2: 0.9469662308692932
# No improvement in validation accuracy.
# Starting Epoch 23
# Epoch 23, Loss: 0.0001
# MSE: 0.00050
# r2: 0.9454108476638794
# No improvement in validation accuracy.
# Starting Epoch 24
# Epoch 24, Loss: 0.0001
# MSE: 0.00061
# r2: 0.9338950514793396
# No improvement in validation accuracy.
# Starting Epoch 25
# Epoch 25, Loss: 0.0002
# MSE: 0.00046
# r2: 0.9504007697105408
# ...saving!...
# Starting Epoch 26
# Epoch 26, Loss: 0.0002
# MSE: 0.00044
# r2: 0.9522638320922852
# ...saving!...
# Starting Epoch 27
# Epoch 27, Loss: 0.0001
# MSE: 0.00047
# r2: 0.9491394758224487
# No improvement in validation accuracy.
# Starting Epoch 28
# Epoch 28, Loss: 0.0001
# MSE: 0.00051
# r2: 0.9451800584793091
# No improvement in validation accuracy.
# Starting Epoch 29
# Epoch 29, Loss: 0.0001
# MSE: 0.00052
# r2: 0.9438559412956238
# No improvement in validation accuracy.
# Starting Epoch 30
# Epoch 30, Loss: 0.0001
# MSE: 0.00049
# r2: 0.9474368691444397
# No improvement in validation accuracy.
# Starting Epoch 31
# Epoch 31, Loss: 0.0001
# MSE: 0.00086
# r2: 0.9066648483276367
# No improvement in validation accuracy.
# Starting Epoch 32
# Epoch 32, Loss: 0.0002
# MSE: 0.00075
# r2: 0.9186243414878845
# No improvement in validation accuracy.
# Starting Epoch 33
# Epoch 33, Loss: 0.0002
# MSE: 0.00049
# r2: 0.9470367431640625
# No improvement in validation accuracy.
# Starting Epoch 34
# Epoch 34, Loss: 0.0002
# MSE: 0.00045
# r2: 0.9517963528633118
# No improvement in validation accuracy.
# Starting Epoch 35
# Epoch 35, Loss: 0.0001
# MSE: 0.00044
# r2: 0.9522265195846558
# No improvement in validation accuracy.
# Starting Epoch 36
# Epoch 36, Loss: 0.0001
# MSE: 0.00052
# r2: 0.9442620277404785
# No improvement in validation accuracy.
# Starting Epoch 37
# Epoch 37, Loss: 0.0001
# MSE: 0.00063
# r2: 0.9318090677261353
# No improvement in validation accuracy.
# Starting Epoch 38
# Epoch 38, Loss: 0.0002
# MSE: 0.00056
# r2: 0.9396230578422546
# No improvement in validation accuracy.
# Starting Epoch 39
# Epoch 39, Loss: 0.0002
# MSE: 0.00044
# r2: 0.9522705078125
# ...saving!...
# Starting Epoch 40
# Epoch 40, Loss: 0.0001
# MSE: 0.00048
# r2: 0.9475801587104797
# No improvement in validation accuracy.
# Starting Epoch 41
# Epoch 41, Loss: 0.0001
# MSE: 0.00044
# r2: 0.9525007605552673
# ...saving!...
# Starting Epoch 42
# Epoch 42, Loss: 0.0001
# MSE: 0.00054
# r2: 0.9414178729057312
# No improvement in validation accuracy.
# Starting Epoch 43
# Epoch 43, Loss: 0.0001
# MSE: 0.00056
# r2: 0.9389449954032898
# No improvement in validation accuracy.
# Starting Epoch 44
# Epoch 44, Loss: 0.0001
# MSE: 0.00056
# r2: 0.9396848678588867
# No improvement in validation accuracy.
# Starting Epoch 45
# Epoch 45, Loss: 0.0001
# MSE: 0.00056
# r2: 0.9389361143112183
# No improvement in validation accuracy.
# Starting Epoch 46
# Epoch 46, Loss: 0.0002
# MSE: 0.00066
# r2: 0.9286673069000244
# No improvement in validation accuracy.
# Starting Epoch 47
# Epoch 47, Loss: 0.0002
# MSE: 0.00057
# r2: 0.9379071593284607
# No improvement in validation accuracy.
# Starting Epoch 48
# Epoch 48, Loss: 0.0002
# MSE: 0.00052
# r2: 0.9439724087715149
# No improvement in validation accuracy.
# Starting Epoch 49
# Epoch 49, Loss: 0.0001
# MSE: 0.00048
# r2: 0.947883665561676
# No improvement in validation accuracy.
# Starting Epoch 50
# Epoch 50, Loss: 0.0001
# MSE: 0.00048
# r2: 0.9482663869857788
# No improvement in validation accuracy.
# Starting Epoch 51
# Epoch 51, Loss: 0.0001
# MSE: 0.00052
# r2: 0.943233847618103
# No improvement in validation accuracy.
# Starting Epoch 52
# Epoch 52, Loss: 0.0001
# MSE: 0.00058
# r2: 0.9373620748519897
# No improvement in validation accuracy.
# Starting Epoch 53
# Epoch 53, Loss: 0.0001
# MSE: 0.00060
# r2: 0.9348489046096802
# No improvement in validation accuracy.
# Starting Epoch 54
# Epoch 54, Loss: 0.0001
# MSE: 0.00062
# r2: 0.9334492683410645
# No improvement in validation accuracy.
# Starting Epoch 55
# Epoch 55, Loss: 0.0001
# MSE: 0.00055
# r2: 0.9402408599853516
# No improvement in validation accuracy.
# Starting Epoch 56
# Epoch 56, Loss: 0.0002
# MSE: 0.00058
# r2: 0.9370542168617249
# No improvement in validation accuracy.
# Starting Epoch 57
# Epoch 57, Loss: 0.0002
# MSE: 0.00071
# r2: 0.9235170483589172
# No improvement in validation accuracy.
# Starting Epoch 58
# Epoch 58, Loss: 0.0002
# MSE: 0.00077
# r2: 0.9167641401290894
# No improvement in validation accuracy.
# Starting Epoch 59
# Epoch 59, Loss: 0.0002
# MSE: 0.00072
# r2: 0.9219763278961182
# No improvement in validation accuracy.
# Starting Epoch 60
# Epoch 60, Loss: 0.0001
# MSE: 0.00066
# r2: 0.9286254048347473
# No improvement in validation accuracy.
# Starting Epoch 61
# Epoch 61, Loss: 0.0001
# MSE: 0.00061
# r2: 0.9340590238571167
# No improvement in validation accuracy.
# Starting Epoch 62
# Epoch 62, Loss: 0.0001
# MSE: 0.00058
# r2: 0.9374439716339111
# No improvement in validation accuracy.
# Epoch 00063: reducing learning rate of group 0 to 5.0000e-05.
# Starting Epoch 63
# Epoch 63, Loss: 0.0001
# MSE: 0.00052
# r2: 0.9439321160316467
# No improvement in validation accuracy.
# Starting Epoch 64
# Epoch 64, Loss: 0.0001
# MSE: 0.00051
# r2: 0.9445317983627319
# No improvement in validation accuracy.
# Starting Epoch 65
# Epoch 65, Loss: 0.0001
# MSE: 0.00051
# r2: 0.9446070194244385
# No improvement in validation accuracy.
# Starting Epoch 66
# Epoch 66, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9445956945419312
# No improvement in validation accuracy.
# Starting Epoch 67
# Epoch 67, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9445096254348755
# No improvement in validation accuracy.
# Starting Epoch 68
# Epoch 68, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9444547891616821
# No improvement in validation accuracy.
# Starting Epoch 69
# Epoch 69, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9443584084510803
# No improvement in validation accuracy.
# Starting Epoch 70
# Epoch 70, Loss: 0.0000
# MSE: 0.00052
# r2: 0.944282054901123
# No improvement in validation accuracy.
# Starting Epoch 71
# Epoch 71, Loss: 0.0000
# MSE: 0.00052
# r2: 0.9441515207290649
# No improvement in validation accuracy.
# Starting Epoch 72
# Epoch 72, Loss: 0.0000
# MSE: 0.00052
# r2: 0.9439742565155029
# No improvement in validation accuracy.
# Starting Epoch 73
# Epoch 73, Loss: 0.0000
# MSE: 0.00052
# r2: 0.9438355565071106
# No improvement in validation accuracy.
# Starting Epoch 74
# Epoch 74, Loss: 0.0000
# MSE: 0.00052
# r2: 0.9436003565788269
# No improvement in validation accuracy.
# Starting Epoch 75
# Epoch 75, Loss: 0.0000
# MSE: 0.00052
# r2: 0.9433467388153076
# No improvement in validation accuracy.
# Starting Epoch 76
# Epoch 76, Loss: 0.0000
# MSE: 0.00053
# r2: 0.9431739449501038
# No improvement in validation accuracy.
# Starting Epoch 77
# Epoch 77, Loss: 0.0000
# MSE: 0.00053
# r2: 0.9430288076400757
# No improvement in validation accuracy.
# Starting Epoch 78
# Epoch 78, Loss: 0.0000
# MSE: 0.00053
# r2: 0.9423677921295166
# No improvement in validation accuracy.
# Starting Epoch 79
# Epoch 79, Loss: 0.0000
# MSE: 0.00053
# r2: 0.9425020217895508
# No improvement in validation accuracy.
# Starting Epoch 80
# Epoch 80, Loss: 0.0000
# MSE: 0.00054
# r2: 0.9412878751754761
# No improvement in validation accuracy.
# Starting Epoch 81
# Epoch 81, Loss: 0.0000
# MSE: 0.00053
# r2: 0.9427158236503601
# No improvement in validation accuracy.
# Starting Epoch 82
# Epoch 82, Loss: 0.0000
# MSE: 0.00058
# r2: 0.9377265572547913
# No improvement in validation accuracy.
# Starting Epoch 83
# Epoch 83, Loss: 0.0000
# MSE: 0.00053
# r2: 0.9428383111953735
# No improvement in validation accuracy.
# Epoch 00084: reducing learning rate of group 0 to 2.5000e-05.
# Starting Epoch 84
# Epoch 84, Loss: 0.0001
# MSE: 0.00052
# r2: 0.9441753625869751
# No improvement in validation accuracy.
# Starting Epoch 85
# Epoch 85, Loss: 0.0001
# MSE: 0.00049
# r2: 0.9468536376953125
# No improvement in validation accuracy.
# Starting Epoch 86
# Epoch 86, Loss: 0.0001
# MSE: 0.00049
# r2: 0.9473540782928467
# No improvement in validation accuracy.
# Starting Epoch 87
# Epoch 87, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9473518133163452
# No improvement in validation accuracy.
# Starting Epoch 88
# Epoch 88, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9473784565925598
# No improvement in validation accuracy.
# Starting Epoch 89
# Epoch 89, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9473087787628174
# No improvement in validation accuracy.
# Starting Epoch 90
# Epoch 90, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9472374320030212
# No improvement in validation accuracy.
# Starting Epoch 91
# Epoch 91, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9471547603607178
# No improvement in validation accuracy.
# Starting Epoch 92
# Epoch 92, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470842480659485
# No improvement in validation accuracy.
# Starting Epoch 93
# Epoch 93, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470124840736389
# No improvement in validation accuracy.
# Starting Epoch 94
# Epoch 94, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9469180703163147
# No improvement in validation accuracy.
# Starting Epoch 95
# Epoch 95, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9468315839767456
# No improvement in validation accuracy.
# Starting Epoch 96
# Epoch 96, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9467684030532837
# No improvement in validation accuracy.
# Starting Epoch 97
# Epoch 97, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9466870427131653
# No improvement in validation accuracy.
# Starting Epoch 98
# Epoch 98, Loss: 0.0000
# MSE: 0.00049
# r2: 0.946602463722229
# No improvement in validation accuracy.
# Starting Epoch 99
# Epoch 99, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9465475678443909
# No improvement in validation accuracy.
# Starting Epoch 100
# Epoch 100, Loss: 0.0000
# MSE: 0.00050
# r2: 0.946456253528595
# No improvement in validation accuracy.
# Starting Epoch 101
# Epoch 101, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9463992714881897
# No improvement in validation accuracy.
# Starting Epoch 102
# Epoch 102, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9463143944740295
# No improvement in validation accuracy.
# Starting Epoch 103
# Epoch 103, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9462660551071167
# No improvement in validation accuracy.
# Starting Epoch 104
# Epoch 104, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9461690187454224
# No improvement in validation accuracy.
# Epoch 00105: reducing learning rate of group 0 to 1.2500e-05.
# Starting Epoch 105
# Epoch 105, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9443600177764893
# No improvement in validation accuracy.
# Starting Epoch 106
# Epoch 106, Loss: 0.0000
# MSE: 0.00054
# r2: 0.9413847923278809
# No improvement in validation accuracy.
# Starting Epoch 107
# Epoch 107, Loss: 0.0000
# MSE: 0.00055
# r2: 0.9401715993881226
# No improvement in validation accuracy.
# Starting Epoch 108
# Epoch 108, Loss: 0.0000
# MSE: 0.00054
# r2: 0.9417496919631958
# No improvement in validation accuracy.
# Starting Epoch 109
# Epoch 109, Loss: 0.0000
# MSE: 0.00052
# r2: 0.9437040686607361
# No improvement in validation accuracy.
# Starting Epoch 110
# Epoch 110, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9450467824935913
# No improvement in validation accuracy.
# Starting Epoch 111
# Epoch 111, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9458792209625244
# No improvement in validation accuracy.
# Starting Epoch 112
# Epoch 112, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9463616609573364
# No improvement in validation accuracy.
# Starting Epoch 113
# Epoch 113, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9466792941093445
# No improvement in validation accuracy.
# Starting Epoch 114
# Epoch 114, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9468584060668945
# No improvement in validation accuracy.
# Starting Epoch 115
# Epoch 115, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9469678997993469
# No improvement in validation accuracy.
# Starting Epoch 116
# Epoch 116, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470251798629761
# No improvement in validation accuracy.
# Starting Epoch 117
# Epoch 117, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470741748809814
# No improvement in validation accuracy.
# Starting Epoch 118
# Epoch 118, Loss: 0.0000
# MSE: 0.00049
# r2: 0.947089433670044
# No improvement in validation accuracy.
# Starting Epoch 119
# Epoch 119, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470996260643005
# No improvement in validation accuracy.
# Starting Epoch 120
# Epoch 120, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9471011161804199
# No improvement in validation accuracy.
# Starting Epoch 121
# Epoch 121, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9471048712730408
# No improvement in validation accuracy.
# Starting Epoch 122
# Epoch 122, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470902681350708
# No improvement in validation accuracy.
# Starting Epoch 123
# Epoch 123, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470686316490173
# No improvement in validation accuracy.
# Starting Epoch 124
# Epoch 124, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470382928848267
# No improvement in validation accuracy.
# Starting Epoch 125
# Epoch 125, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9470105767250061
# No improvement in validation accuracy.
# Epoch 00126: reducing learning rate of group 0 to 6.2500e-06.
# Starting Epoch 126
# Epoch 126, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9455493688583374
# No improvement in validation accuracy.
# Starting Epoch 127
# Epoch 127, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9449569582939148
# No improvement in validation accuracy.
# Starting Epoch 128
# Epoch 128, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9448845982551575
# No improvement in validation accuracy.
# Starting Epoch 129
# Epoch 129, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9450485706329346
# No improvement in validation accuracy.
# Starting Epoch 130
# Epoch 130, Loss: 0.0000
# MSE: 0.00051
# r2: 0.9452630281448364
# No improvement in validation accuracy.
# Starting Epoch 131
# Epoch 131, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9454626441001892
# No improvement in validation accuracy.
# Starting Epoch 132
# Epoch 132, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9456158876419067
# No improvement in validation accuracy.
# Starting Epoch 133
# Epoch 133, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9457481503486633
# No improvement in validation accuracy.
# Starting Epoch 134
# Epoch 134, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9458470940589905
# No improvement in validation accuracy.
# Starting Epoch 135
# Epoch 135, Loss: 0.0000
# MSE: 0.00050
# r2: 0.945936918258667
# No improvement in validation accuracy.
# Starting Epoch 136
# Epoch 136, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9460070729255676
# No improvement in validation accuracy.
# Starting Epoch 137
# Epoch 137, Loss: 0.0000
# MSE: 0.00050
# r2: 0.946074366569519
# No improvement in validation accuracy.
# Starting Epoch 138
# Epoch 138, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9461325407028198
# No improvement in validation accuracy.
# Starting Epoch 139
# Epoch 139, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9461864233016968
# No improvement in validation accuracy.
# Starting Epoch 140
# Epoch 140, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9462340474128723
# No improvement in validation accuracy.
# Starting Epoch 141
# Epoch 141, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9462743401527405
# No improvement in validation accuracy.
# Starting Epoch 142
# Epoch 142, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9463105201721191
# No improvement in validation accuracy.
# Starting Epoch 143
# Epoch 143, Loss: 0.0000
# MSE: 0.00050
# r2: 0.946347713470459
# No improvement in validation accuracy.
# Starting Epoch 144
# Epoch 144, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9463790655136108
# No improvement in validation accuracy.
# Starting Epoch 145
# Epoch 145, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9464129209518433
# No improvement in validation accuracy.
# Starting Epoch 146
# Epoch 146, Loss: 0.0000
# MSE: 0.00050
# r2: 0.9464454054832458
# No improvement in validation accuracy.
# Epoch 00147: reducing learning rate of group 0 to 3.1250e-06.
# Starting Epoch 147
# Epoch 147, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9471021294593811
# No improvement in validation accuracy.
# Starting Epoch 148
# Epoch 148, Loss: 0.0000
# MSE: 0.00049
# r2: 0.947245180606842
# No improvement in validation accuracy.
# Starting Epoch 149
# Epoch 149, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9473307132720947
# No improvement in validation accuracy.
# Starting Epoch 150
# Epoch 150, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9473912715911865
# No improvement in validation accuracy.
# Starting Epoch 151
# Epoch 151, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9474402070045471
# No improvement in validation accuracy.
# Starting Epoch 152
# Epoch 152, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9474785327911377
# No improvement in validation accuracy.
# Starting Epoch 153
# Epoch 153, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9475087523460388
# No improvement in validation accuracy.
# Starting Epoch 154
# Epoch 154, Loss: 0.0000
# MSE: 0.00049
# r2: 0.9475322961807251
# No improvement in validation accuracy.
# Starting Epoch 155
# Epoch 155, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9475553035736084
# No improvement in validation accuracy.
# Starting Epoch 156
# Epoch 156, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9475727677345276
# No improvement in validation accuracy.
# Starting Epoch 157
# Epoch 157, Loss: 0.0000
# MSE: 0.00048
# r2: 0.947588324546814
# No improvement in validation accuracy.
# Starting Epoch 158
# Epoch 158, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9475994110107422
# No improvement in validation accuracy.
# Starting Epoch 159
# Epoch 159, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9476118087768555
# No improvement in validation accuracy.
# Starting Epoch 160
# Epoch 160, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9476220011711121
# No improvement in validation accuracy.
# Starting Epoch 161
# Epoch 161, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9476313591003418
# No improvement in validation accuracy.
# Starting Epoch 162
# Epoch 162, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9476431012153625
# No improvement in validation accuracy.
# Starting Epoch 163
# Epoch 163, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9476512670516968
# No improvement in validation accuracy.
# Starting Epoch 164
# Epoch 164, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9476590752601624
# No improvement in validation accuracy.
# Starting Epoch 165
# Epoch 165, Loss: 0.0000
# MSE: 0.00048
# r2: 0.947665274143219
# No improvement in validation accuracy.
# Starting Epoch 166
# Epoch 166, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9476738572120667
# No improvement in validation accuracy.
# Starting Epoch 167
# Epoch 167, Loss: 0.0000
# Epoch 172, Loss: 0.0000
# MSE: 0.00048
# r2: 0.948141872882843
# No improvement in validation accuracy.
# Starting Epoch 173
# Epoch 173, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9481632709503174
# No improvement in validation accuracy.
# Starting Epoch 174
# Epoch 174, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9481800198554993
# No improvement in validation accuracy.
# Starting Epoch 175
# Epoch 175, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9481942057609558
# No improvement in validation accuracy.
# Starting Epoch 176
# Epoch 176, Loss: 0.0000
# MSE: 0.00048
# r2: 0.948205828666687
# No improvement in validation accuracy.
# Starting Epoch 177
# Epoch 177, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482158422470093
# No improvement in validation accuracy.
# Starting Epoch 178
# Epoch 178, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482250809669495
# No improvement in validation accuracy.
# Starting Epoch 179
# Epoch 179, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482321739196777
# No improvement in validation accuracy.
# Starting Epoch 180
# Epoch 180, Loss: 0.0000
# MSE: 0.00048
# r2: 0.948238730430603
# No improvement in validation accuracy.
# Starting Epoch 181
# Epoch 181, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482439756393433
# No improvement in validation accuracy.
# Starting Epoch 182
# Epoch 182, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482495188713074
# No improvement in validation accuracy.
# Starting Epoch 183
# Epoch 183, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482536911964417
# No improvement in validation accuracy.
# Starting Epoch 184
# Epoch 184, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482578635215759
# No improvement in validation accuracy.
# Starting Epoch 185
# Epoch 185, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482617974281311
# No improvement in validation accuracy.
# Starting Epoch 186
# Epoch 186, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482648372650146
# No improvement in validation accuracy.
# Starting Epoch 187
# Epoch 187, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9482685923576355
# No improvement in validation accuracy.
# Starting Epoch 188
# Epoch 188, Loss: 0.0000
# MSE: 0.00048
# r2: 0.948271632194519
# No improvement in validation accuracy.
# Epoch 00189: reducing learning rate of group 0 to 7.8125e-07.
# Starting Epoch 189
# Epoch 189, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9484909772872925
# No improvement in validation accuracy.
# Starting Epoch 190
# Epoch 190, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9485349655151367
# No improvement in validation accuracy.
# Starting Epoch 191
# Epoch 191, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9485689997673035
# No improvement in validation accuracy.
# Starting Epoch 192
# Epoch 192, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9485957622528076
# No improvement in validation accuracy.
# Starting Epoch 193
# Epoch 193, Loss: 0.0000
# MSE: 0.00048
# r2: 0.9486169219017029
# No improvement in validation accuracy.
# Starting Epoch 194
# Epoch 194, Loss: 0.0000
# MSE: 0.00047
# r2: 0.9486337900161743
# No improvement in validation accuracy.
# Starting Epoch 195
# Epoch 195, Loss: 0.0000
# MSE: 0.00047
# r2: 0.9486470222473145
# No improvement in validation accuracy.
# Starting Epoch 196
# Epoch 196, Loss: 0.0000
# MSE: 0.00047
# r2: 0.9486575722694397
# No improvement in validation accuracy.
# Starting Epoch 197
# Epoch 197, Loss: 0.0000
# MSE: 0.00047
# r2: 0.9486662745475769
# No improvement in validation accuracy.
# Starting Epoch 198
# Epoch 198, Loss: 0.0000
# MSE: 0.00047
# r2: 0.9486734867095947
# No improvement in validation accuracy.
# Starting Epoch 199
# Epoch 199, Loss: 0.0000
# MSE: 0.00047
# r2: 0.9486793279647827
# No improvement in validation accuracy.

# %% [markdown]
# ## ANN

# %%
rem = Data_train.shape
input_shape = (rem[1],rem[2],rem[3]) # Example input shape (C, H, W)
model = RegressionANN(input_shape=input_shape, num_classes=1)
model.fc0.weight.data = torch.normal(mean=0,std=(1/458),size=(1024, 458))
model.fc0.bias.data.fill_(0)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, verbose=True)

train_dataset = SpatialDataset_ANN(Data_train,Y_train)
val_dataset = SpatialDataset_ANN(Data_val,Y_val)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
num_epochs = 20

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    print(f"Starting Epoch {epoch}")
    nsampsseen = 0
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        nsampsseen += inputs.shape[0]
        if nsampsseen > 40000:
            break
    epoch_loss = running_loss / nsampsseen
    print(f"Epoch {epoch}, Loss: {epoch_loss:.4f}")

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    mse_val_batch=[]
    with torch.no_grad():  # In validation phase, we don't need to compute gradients
        for inputs, labels in val_loader:
            outputs = model(inputs)
            mse_val_batch.append((torch.mean((outputs-labels)**2)))
            
    # Calculate and print validation accuracy
    mse_tot=torch.mean(torch.tensor(mse_val_batch))
    
    print(f"MSE: {mse_tot:.5f}")
    print( f"r2: {1-(mse_tot/np.var(Y_val))}")
    
    if epoch == 0:
        print('...saved first epoch...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    elif mse_tot<best_acc:
        print('...saving!...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    else:
        print('No improvement in validation accuracy.')
    # Step the scheduler on each epoch
    scheduler.step(mse_tot)
plt.plot(labels.detach().numpy())
plt.plot(best_mod(inputs).detach().numpy())
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
rem = Data_train.shape
input_shape = (rem[1],rem[2],rem[3]) # Example input shape (C, H, W)
model = Regression_Linear(input_shape=input_shape, num_classes=1)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.02)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)

train_dataset = SpatialDataset_ANN(Data_train,Y_train)
val_dataset = SpatialDataset_ANN(Data_val,Y_val)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
num_epochs = 200

for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    print(f"Starting Epoch {epoch}")
    nsampsseen = 0
    running_loss = 0.0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
        nsampsseen += inputs.shape[0]
        if nsampsseen > 100000:
            break
    epoch_loss = running_loss / nsampsseen
    print(f"Epoch {epoch}, Loss: {epoch_loss:.4f}")

    # Validation loop
    model.eval()  # Set the model to evaluation mode
    correct = 0
    total = 0
    mse_val_batch=[]
    with torch.no_grad():  # In validation phase, we don't need to compute gradients
        for inputs, labels in val_loader:
            outputs = model(inputs)
            mse_val_batch.append((torch.mean((outputs-labels)**2)))
            
    # Calculate and print validation accuracy
    mse_tot=torch.mean(torch.tensor(mse_val_batch))
    
    print(f"MSE: {mse_tot:.5f}")
    print( f"r2: {1-(mse_tot/np.var(Y_val))}")
    
    if epoch == 0:
        print('...saved first epoch...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    elif mse_tot<best_acc:
        print('...saving!...')
        best_mod = copy.deepcopy(model)
        best_acc = copy.deepcopy(mse_tot)
    else:
        print('No improvement in validation accuracy.')
    # Step the scheduler on each epoch
    scheduler.step(mse_tot)
# Out:
# Starting Epoch 0
# Epoch 0, Loss: 0.1069
# MSE: 0.08134
# r2: -7.798417091369629
# ...saved first epoch...
# Starting Epoch 1
# Epoch 1, Loss: 0.0950
# MSE: 0.09404
# r2: -9.17148494720459
# No improvement in validation accuracy.
# Starting Epoch 2
# Epoch 2, Loss: 0.1150
# MSE: 0.01892
# r2: -1.0464820861816406
# ...saving!...
# Starting Epoch 3
# Epoch 3, Loss: 0.1112
# MSE: 0.01589
# r2: -0.7184035778045654
# ...saving!...
# Starting Epoch 4
# Epoch 4, Loss: 0.0937
# MSE: 0.15636
# r2: -15.912834167480469
# No improvement in validation accuracy.
# Starting Epoch 5
# Epoch 5, Loss: 0.1111
# MSE: 0.09800
# r2: -9.599940299987793
# No improvement in validation accuracy.
# Starting Epoch 6
# Epoch 6, Loss: 0.0992
# MSE: 0.02661
# r2: -1.8779819011688232
# No improvement in validation accuracy.
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-03.
# Starting Epoch 7
# Epoch 7, Loss: 0.0246
# MSE: 0.01161
# r2: -0.255520224571228
# ...saving!...
# Starting Epoch 8
# Epoch 8, Loss: 0.0311
# MSE: 0.01253
# r2: -0.35570454597473145
# No improvement in validation accuracy.
# Starting Epoch 9
# Epoch 9, Loss: 0.0356
# MSE: 0.01240
# r2: -0.34080076217651367
# No improvement in validation accuracy.
# Starting Epoch 10
# Epoch 10, Loss: 0.0332
# MSE: 0.01199
# r2: -0.29729580879211426
# No improvement in validation accuracy.
# Epoch 00015: reducing learning rate of group 0 to 2.5000e-03.
# Starting Epoch 11
# Epoch 11, Loss: 0.0132
# MSE: 0.01063
# r2: -0.14940130710601807
# ...saving!...
# Starting Epoch 12
# Epoch 12, Loss: 0.0158
# MSE: 0.01057
# r2: -0.14384186267852783
# ...saving!...
# Starting Epoch 13
# Epoch 13, Loss: 0.0158
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 27
#      25 mse_val_batch=[]
#      26 with torch.no_grad():  # In validation phase, we don't need to compute gradients
# ---> 27     for inputs, labels in val_loader:
#      28         outputs = model(inputs)
#      29         mse_val_batch.append((torch.mean((outputs-labels)**2)))
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /glade/work/wchapman/miniconda3.1/envs/MLWPS/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# KeyboardInterrupt:

# %%
plt.plot(labels.detach().numpy())
plt.plot(outputs.detach().numpy())
